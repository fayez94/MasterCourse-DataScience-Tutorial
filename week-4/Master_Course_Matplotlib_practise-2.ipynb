# %% [markdown]
# # Matplotlib

# %%
# Notebook Magic Line
# create visualizations in the notebook itself
# %matplotlib inline

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# !gdown --id 1Hy7eMz-fdQ8s3q-eeLhCe6qhYp5HSPwH
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Hy7eMz-fdQ8s3q-eeLhCe6qhYp5HSPwH
# To: /content/best_cs_scientific_details.csv
# 100% 310k/310k [00:00<00:00, 103MB/s]

# %%
df = pd.read_csv("/content/best_cs_scientific_details.csv")
df
# Out:
#       World Rank  National Rank                 Name  \
# 0              1              1        Yoshua Bengio
# 1              2              1         Anil K. Jain
# 2              3              2           Jiawei Han
# 3              4              1     Andrew Zisserman
# 4              5              3    Michael I. Jordan
# ...          ...            ...                  ...
# 1995        1996           1091          Mark Dredze
# 1996        1997           1092  Robbert van Renesse
# 1997        1998           1093          Wen-tau Yih
# 1998        1999           1094     Carla E. Brodley
# 1999        2000              2     Moustafa Youssef
#
#                                              Image URLs  \
# 0     https://s.research.com/images/aec914cd458a74e2...
# 1     https://s.research.com/images/2a967b4499197336...
# 2     https://s.research.com/images/42382fdef4ef0953...
# 3     https://s.research.com/images/2a3913cff9795e86...
# 4     https://s.research.com/images/56e4335ff90165e8...
# ...                                                 ...
# 1995  https://s.research.com/images/c8937fe3f25c3793...
# 1996  https://s.research.com/images/009f347fdbb13cf5...
# 1997  https://s.research.com/images/33b14ab44bc2a199...
# 1998  https://s.research.com/images/59d9973db42f7a16...
# 1999  https://s.research.com/images/74f32cc145d7b93a...
#
#                                      Affiliation         Country  H-Index  \
# 0                         University of Montreal          Canada      208
# 1                      Michigan State University   United States      207
# 2     University of Illinois at Urbana-Champaign   United States      189
# 3                           University of Oxford  United Kingdom      188
# 4                       University of California        Berkeley      186
# ...                                          ...             ...      ...
# 1995                    Johns Hopkins University   United States       64
# 1996                          Cornell University   United States       64
# 1997                    Facebook (United States)   United States       64
# 1998                     Northeastern University   United States       64
# 1999                American University in Cairo           Egypt       64
#
#       Citation  #DBLP
# 0       547028    847
# 1       260075   1009
# 2       216422   1266
# 3       282705    782
# 4       242697    836
# ...        ...    ...
# 1995     20509    267
# 1996     19870    234
# 1997     19319    134
# 1998     19289    152
# 1999     19260    279
#
# [2000 rows x 9 columns]

# %% [markdown]
# ## Line Chart

# %%
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

# %%
country_cnt = df['Country'].value_counts().to_dict()

countries = list(country_cnt.keys())
cnt = list(country_cnt.values())

plt.rcParams["figure.figsize"] = (15,5)

plt.title("Presence of Countries")

plt.plot(cnt,'g')

plt.xticks(ticks=range(len(countries)),labels=countries, rotation='vertical')

plt.show()

# %% [markdown]
# ## Bar Plot

# %%
country_cnt = df['Country'].value_counts().to_dict()

countries = list(country_cnt.keys())
cnt = list(country_cnt.values())

plt.rcParams["figure.figsize"] = (20,10)

plt.xticks(ticks=range(len(countries)),labels=countries, rotation='vertical')

plt.title("Presence of Countries")

plt.bar(countries,cnt,color=['red','blue','green','lightblue', 'brown'])

plt.show()

# %% [markdown]
# ## Histogram

# %%
plt.title("#DBLP Distribution")

plt.xlabel('#DBLP')

plt.rcParams["figure.figsize"] = (10,5)

plt.ylabel('Frequency')

plt.hist(df['#DBLP'],bins=100,color='green') # bins define how many ranges should be considered from min to max

plt.show()

# %% [markdown]
# ## Box Plots

# %%
outliers = dict(markerfacecolor = 'r', marker = 'D')
plt.title('#DBLP Distribution')
plt.boxplot(df['#DBLP'],labels=['#DBLP'],flierprops=outliers)
plt.show()

# %% [markdown]
# ### Multiple blotplot in one

# %%
data = df[['#DBLP','H-Index']]
outliers = dict(markerfacecolor = 'g', marker = 'o')
plt.rcParams["figure.figsize"] = (20,10)
fig,ax = plt.subplots()
plt.boxplot(data.values,labels=['#DBLP','H-index'],flierprops=outliers)
plt.show()

# %%
data = df[['#DBLP','H-Index','Citation']]
outliers = dict(markerfacecolor = 'b', marker = 'D')
plt.rcParams["figure.figsize"] = (20,10)
fig,ax = plt.subplots()
plt.boxplot(data.values,labels=['#DBLP','H-index','Citation'],flierprops=outliers)
plt.show()

# %% [markdown]
# ## Violin Plots
# shows density distribution

# %%
data = df[['#DBLP','H-Index']]

plt.rcParams["figure.figsize"] = (20,10)

fig,ax = plt.subplots()

plt.xticks(ticks=[1,2],labels=['#DBLP','H-Index'])

plt.violinplot(data.values)

plt.show()

# %% [markdown]
# ## Scatter Plots
# shows relative distribution of two variables

# %%
plt.xlabel('#DBLP')
plt.ylabel('World Rank')

plt.scatter(df['#DBLP'],df['World Rank'])

# %%
plt.xlabel('Citation')
plt.ylabel('World Rank')

plt.scatter(df['Citation'],df['World Rank'])

# %% [markdown]
# ## Bubble Plots
# relative distribution among 3 variables

# %%
plt.xlabel('Citation')
plt.ylabel('#DBLP')

plt.scatter(df['Citation'][:200],df['#DBLP'][:200],s=df['World Rank'][:200]) # s is the size of the bubble

# %% [markdown]
# Useful Resources for more exploration: <br/>
# i) https://matplotlib.org/stable/gallery/index.html <br/>
# ii) https://www.python-graph-gallery.com
